# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
#set labelsize
plt.rc('xtick', labelsize=20) 
plt.rc('ytick', labelsize=20)

# %%
#load all the necessary data for the analysis miRNA and mRNAs tables
# all the data can be found in the data section of the github profile
ad2 = pd.read_csv("../files/normalized_counts_DESEQ2/iPSC_differentiation_mRNA_only_AD2-results-with-normalized.csv")
ad3 = pd.read_csv("../files/normalized_counts_DESEQ2/iPSC_differentiation_mRNA_only_AD3-results-with-normalized.csv")
eigthy = pd.read_csv("../files/normalized_counts_DESEQ2/iPSC_differentiation_mRNA_only_840-results-with-normalized.csv")
ad2_mir = pd.read_csv("../files/normalized_counts_DESEQ2/AD2_miRNAs_timeline_ltr-results-with-normalized.csv")
ad3_mir = pd.read_csv("../files/normalized_counts_DESEQ2/AD3_miRNAs_timeline_ltr-results-with-normalized.csv")
eigthy_mir = pd.read_csv("../files/normalized_counts_DESEQ2/840_miRNAs_timeline_ltr-results-with-normalized.csv")

# this one is not shared with Github, file size is exceeding the limit
network_analysis = pd.read_csv("../files/WGCNA/consensusAnalysis-CombinedNetworkResults_filtered_power20.csv")
network_analysis
# Out:
#        Unnamed: 0            Probe  ModuleLabel ModuleColor  kME.set1.ME0  \
# 0               1  ENSG00000000003            9     magenta     -0.313623
# 1               2  ENSG00000000419            2        blue     -0.770760
# 2               3  ENSG00000000457           21     darkred      0.341634
# 3               4  ENSG00000000460            5       green     -0.644781
# 4               5  ENSG00000000938            3       brown     -0.427813
# ...           ...              ...          ...         ...           ...
# 20877       20878  ENSG00000288438            0        grey      0.235773
# 20878       20879  ENSG00000288442            0        grey      0.373237
# 20879       20880  ENSG00000288457            3       brown     -0.112296
# 20880       20881  ENSG00000288475           35     sienna3     -0.788811
# 20881       20882  ENSG00000288518           28     skyblue      0.266027
#
#        kME.set2.ME0  kME.set3ME0  p.kME.set1.ME0  p.kME.set2.ME0  \
# 0          0.434724     0.532164        0.205035        0.071412
# 1          0.505929     0.662603        0.000181        0.032181
# 2          0.847365    -0.202355        0.165276        0.000009
# 3          0.673157     0.573338        0.003865        0.002199
# 4         -0.003697     0.416079        0.076554        0.988384
# ...             ...          ...             ...             ...
# 20877     -0.133788     0.311840        0.346264        0.596630
# 20878      0.693385     0.619323        0.127114        0.001418
# 20879     -0.163249     0.414856        0.657307        0.517472
# 20880      0.294828    -0.331371        0.000100        0.234961
# 20881      0.467304     0.645586        0.285968        0.050543
#
#        p.kME.set3ME0  ...  kME.set1.ME49  kME.set2.ME49  kME.set3ME49  \
# 0           0.023005  ...      -0.147019      -0.080796     -0.222527
# 1           0.002731  ...       0.815932       0.708635      0.792421
# 2           0.420666  ...      -0.491100       0.037111     -0.606937
# 3           0.012865  ...       0.747493       0.774611      0.717099
# 4           0.085902  ...       0.587857       0.792100      0.936015
# ...              ...  ...            ...            ...           ...
# 20877       0.207762  ...      -0.267623      -0.098750     -0.166033
# 20878       0.006128  ...      -0.250310      -0.109002      0.322074
# 20879       0.086922  ...       0.341092       0.642759      0.770534
# 20880       0.179181  ...       0.322374       0.384924     -0.233040
# 20881       0.003807  ...      -0.217258      -0.085090      0.352166
#
#        p.kME.set1.ME49  p.kME.set2.ME49  p.kME.set3ME49  Z.kME.meta.ME49  \
# 0             0.560468         0.749954    3.747958e-01        -1.288002
# 1             0.000037         0.000995    8.825690e-05         8.787546
# 2             0.038490         0.883769    7.563544e-03        -3.406669
# 3             0.000363         0.000160    8.097882e-04         8.204279
# 4             0.010296         0.000089    1.154443e-08         9.775878
# ...                ...              ...             ...              ...
# 20877         0.282979         0.696656    5.102544e-01        -1.530062
# 20878         0.316439         0.666802    1.924356e-01        -0.088305
# 20879         0.165990         0.004015    1.826373e-04         6.052352
# 20880         0.191999         0.114717    3.520463e-01         1.421907
# 20881         0.386498         0.737098    1.517867e-01         0.174916
#
#        p.kME.metaME49  external_gene_name    gene_biotype
# 0        1.977454e-01              TSPAN6  protein_coding
# 1        1.528621e-18                DPM1  protein_coding
# 2        6.576076e-04               SCYL3  protein_coding
# 3        2.319788e-16            C1orf112  protein_coding
# 4        1.429121e-22                 FGR  protein_coding
# ...               ...                 ...             ...
# 20877    1.260013e-01          MG910338.3  protein_coding
# 20878    9.296343e-01          AC256231.3      pseudogene
# 20879    1.427463e-09      LJII02000414.1      pseudogene
# 20880    1.550532e-01            CASP8AP2  protein_coding
# 20881    8.611453e-01          AC275572.1      pseudogene
#
# [20882 rows x 406 columns]

# %%
ad3
# Out:
#        Unnamed: 0 ensembl_gene_id_version     baseMean  log2FoldChange  \
# 0               1         ENSG00000000003  1666.928296       -0.042198
# 1               2         ENSG00000000005     4.184037       -3.991389
# 2               3         ENSG00000000419   555.307553       -1.104890
# 3               4         ENSG00000000457   230.389557        0.066240
# 4               5         ENSG00000000460   349.722024       -2.318593
# ...           ...                     ...          ...             ...
# 67003       67004         ENSG00000288518     7.434368        0.536470
# 67004       67005         ENSG00000288519     0.000000             NaN
# 67005       67006         ENSG00000288520     0.000000             NaN
# 67006       67007         ENSG00000288521     0.000000             NaN
# 67007       67008         ENSG00000288522     0.000000             NaN
#
#           lfcSE        stat         pvalue           padj      AD2_1.1  \
# 0      0.086876  279.212851   2.938188e-58   1.259629e-57  1263.725292
# 1      0.984192   79.702569   9.684481e-16   2.205970e-15    18.368100
# 2      0.100358  224.118446   1.948199e-46   7.277783e-46   746.663272
# 3      0.107718   49.423399   1.818229e-09   3.528488e-09   187.354622
# 4      0.114047  806.437835  4.683158e-172  4.893479e-171   529.001285
# ...         ...         ...            ...            ...          ...
# 67003  0.591967   20.573433   9.749775e-04   1.514206e-03     5.510430
# 67004       NaN         NaN            NaN            NaN     0.000000
# 67005       NaN         NaN            NaN            NaN     0.000000
# 67006       NaN         NaN            NaN            NaN     0.000000
# 67007       NaN         NaN            NaN            NaN     0.000000
#
#            AD2_1.2  ...      AD2_9.3     AD2_16.1     AD2_16.2     AD2_16.3  \
# 0      1410.435864  ...  1895.378570  1210.369233  1167.147499  1084.560216
# 1        22.876689  ...     0.000000     0.000000     0.000000     0.666192
# 2       791.005516  ...   596.355757   463.252068   397.236703   441.018958
# 3       204.130456  ...   270.334444   254.295816   265.953784   265.810520
# 4       476.011106  ...   564.968612   327.233376   314.232019   294.456766
# ...            ...  ...          ...          ...          ...          ...
# 67003     6.159109  ...     7.087420    14.784640    15.245758    15.988603
# 67004     0.000000  ...     0.000000     0.000000     0.000000     0.000000
# 67005     0.000000  ...     0.000000     0.000000     0.000000     0.000000
# 67006     0.000000  ...     0.000000     0.000000     0.000000     0.000000
# 67007     0.000000  ...     0.000000     0.000000     0.000000     0.000000
#
#           AD2_26.1     AD2_26.2     AD2_26.3     AD2_36.1     AD2_36.2  \
# 0      1346.295315  1668.213758  1637.762788  1234.909671  1351.087140
# 1         0.000000     0.000000     1.494309     0.964020     0.000000
# 2       376.003753   440.680973   375.071587   347.047214   370.990883
# 3       177.907816   184.624448   186.788639   215.940489   216.854270
# 4       140.055089   163.744302   180.811403    97.366024   110.553157
# ...            ...          ...          ...          ...          ...
# 67003     5.047030     1.098955     0.000000    12.532261     5.315056
# 67004     0.000000     0.000000     0.000000     0.000000     0.000000
# 67005     0.000000     0.000000     0.000000     0.000000     0.000000
# 67006     0.000000     0.000000     0.000000     0.000000     0.000000
# 67007     0.000000     0.000000     0.000000     0.000000     0.000000
#
#           AD2_36.3
# 0      1415.876974
# 1         3.239993
# 2       384.479178
# 3       194.399584
# 4       102.599781
# ...            ...
# 67003     7.559984
# 67004     0.000000
# 67005     0.000000
# 67006     0.000000
# 67007     0.000000
#
# [67008 rows x 26 columns]

# %%
# get rid of the grey module
network_analysis = network_analysis[network_analysis["ModuleColor"] != "grey"] # remove unwanted network allocated as grey
networks = network_analysis.loc[:, ["Probe", "ModuleColor", "external_gene_name", "gene_biotype"]] # restrict the network anaylsis file to only important subsets
network_analysis_mir = pd.read_csv("../files/WGCNA/mirna_consensusAnalysis-CombinedNetworkResults_filtered.csv") # load the wgcna modules
networks_mir = network_analysis_mir.loc[:, ["Probe", "ModuleColor"]] # get the cluster annotations for miRNAs
networks_mir.columns = ["Probe", "ModuleColor"]# do the same for mirnas

# %%
# add the vst counts here for miRNAs obtained from the DEseq2 scripts
# can be found in the data section of the github repository
ad2_normalized_mirna = pd.read_csv("../files/vst_counts_mirna_mrna/AD2_miRNAs_timeline_ltr-vst-transformed-counts.csv")
ad3_normalized_mirna = pd.read_csv("../files/vst_counts_mirna_mrna/AD3_miRNAs_timeline_ltr-vst-transformed-counts.csv")
eight_normalized_mirna = pd.read_csv("../files/vst_counts_mirna_mrna/840_miRNAs_timeline_ltr-vst-transformed-counts.csv")

# %%
# add vst counts for mRNAs obtained from the DEseq2 scripts
#can be found in the data section of the github repository
ad2_normalized_mrna = pd.read_csv("../files/vst_counts_mirna_mrna/AD2_mRNAs_timeline_ltr-vst-transformed-counts.csv")
ad3_normalized_mrna = pd.read_csv("../files/vst_counts_mirna_mrna/AD3_mRNAs_timeline_ltr-vst-transformed-counts.csv", delimiter = ";")
eight_normalized_mrna = pd.read_csv("../files/vst_counts_mirna_mrna/840_mRNAs_timeline_ltr-vst-transformed-counts.csv")

# %%
# get rid of the ensembl.gene id version in the normalized data for merging
ad2_normalized_mrna["Unnamed: 0"] = [i.split(".")[0] for i in ad2_normalized_mrna["Unnamed: 0"]]
ad3_normalized_mrna["Unnamed: 0"] = [i.split(".")[0] for i in ad3_normalized_mrna["Unnamed: 0"]]
eight_normalized_mrna["Unnamed: 0"] = [i.split(".")[0] for i in eight_normalized_mrna["Unnamed: 0"]]

# %%
# get rid of the gene id version in the unnormalized file format
ad2["Row.names"] = [i.split(".")[0] for i in ad2["Row.names"]]
ad3["ensembl_gene_id_version"] = [i.split(".")[0] for i in ad3["ensembl_gene_id_version"]]
eigthy["Row.names"] = [i.split(".")[0] for i in eigthy["Row.names"]]

# %%
#this should be executed if you want to get rid of the genes/mirna that show an expression of below 5 counts in more than three samples
#here you can change the filtering process 
# this part of the script is for the WGCNA analysis if not yet performed 
# this should be used for filtering lowely expressed genes based on arbitrary cutoffs
mask = (ad2.iloc[:,8:].values > 5).sum(axis=1) >= 3
mask_ad3 = (ad3.iloc[:,8:].values > 5).sum(axis=1) >= 3
mask_eighty = (eigthy.iloc[:,8:].values > 5).sum(axis=1) >= 3

#mask the filtered data to obtain data with filter
ad2_prefilter = ad2[mask]
ad3_prefilter = ad3[mask_ad3]
eighty_prefilter = eigthy[mask_eighty]

# get all the genes that are interesected in all three datasets for WGCNA analysis
gesamt = set(ad2_prefilter["Row.names"]) & set(ad3_prefilter["ensembl_gene_id_version"]) & set(eighty_prefilter["Row.names"])
ad2_end = ad2_prefilter[ad2_prefilter["Row.names"].isin(gesamt)]
ad3_end = ad3_prefilter[ad3_prefilter["ensembl_gene_id_version"].isin(gesamt)]
eighty_end = eighty_prefilter[eighty_prefilter["Row.names"].isin(gesamt)]

#uncomment the to_csv function to write the filtered dataset and use it as input for the WGCNA analysis
#ad2_end.to_csv("iPSC_differentiation_mRNA_only_AD2-results-with-normalized_filtered.csv")
#ad3_end.to_csv("iPSC_differentiation_mRNA_only_AD3-results-with-normalized_filtered.csv")
#eighty_end.to_csv("iPSC_differentiation_mRNA_only_840-results-with-normalized_filtered.csv")

#use this as input for the WGCNA analysis

# %%
#WGCNA analysis for miRNAs
mask_mirna = (ad2_mir.iloc[:, 8:].values > 5).sum(axis=1) >= 3
mask_ad3_mirna = (ad3_mir.iloc[:, 8:].values > 5).sum(axis=1) >= 3
mask_eighty_mirna = (eigthy_mir.iloc[:, 8:].values > 5).sum(axis=1) >= 3

#masking process of filtered data
ad2_prefilter_mir = ad2_mir[mask_mirna]
ad3_prefilter_mir = ad3_mir[mask_ad3_mirna]
eighty_prefilter_mir = eigthy_mir[mask_eighty_mirna]

#combined dataset for all three celllines
gesamt_mirna = set(ad2_prefilter_mir["Row.names"]) & set(
    ad3_prefilter_mir["Row.names"]) & set(eighty_prefilter_mir["Row.names"])
ad2_end_mir = ad2_prefilter_mir[ad2_prefilter_mir["Row.names"].isin(
    gesamt_mirna)]
ad3_end_mir = ad3_prefilter_mir[ad3_prefilter_mir["Row.names"].isin(gesamt)]
eighty_end_mir = eighty_prefilter_mir[eighty_prefilter_mir["Row.names"].isin(
    gesamt_mirna)]

#uncomment to save the files
#ad2_end_mir.to_csv()
#ad3_end_mir.to_csv()
#eighty_end_mir.to_csv()
#save this and use this as input
ad2_normalized_mirna
# Out:
def merge_genes(df1, df2, label):
    """script to merge the normalized vst counts with the modules ect for miRNAs and mRNAs
    -> us mirna if you provied counts for miRNAs
    -> df1 -> normalized data
    -> df2 -> vst counts
    output: returns merged dataframe with modules and vst counts per gene """
    print("merging performing")
    merged_df = pd.merge(df1,
                         df2,
                         how="left",
                         left_on=label,
                         right_on="Unnamed: 0").iloc[:, np.r_[1:8, 27:45]]
    return merged_df

# merge vst counts for gene and miRNAs for further downstream analysis
ad2_trial = merge_genes(ad2_end, ad2_normalized_mrna,"Row.names")
ad3_trial = merge_genes(ad3_end, ad3_normalized_mrna, "ensembl_gene_id_version")
eight_trial = merge_genes(eighty_end, eight_normalized_mrna, "Row.names")


#miRNA vst counts for clustering ect.
ad2_trial_mirna = merge_genes(ad2_mir, ad2_normalized_mirna, "Row.names")
ad3_trial_mirna = merge_genes(ad3_mir, ad3_normalized_mirna, "Row.names")
eight_trial_mirna = merge_genes(eigthy_mir, eight_normalized_mirna, "Row.names")
# Out:
# merging performing
# merging performing
# merging performing
# merging performing
# merging performing
# merging performing

# %%
#mirna_expression = pd.concat([ad2_mir,ad3_mir,eigthy_mir])
#mirna_expression
ad2_exp_mir = pd.DataFrame(ad2_trial_mirna.set_index("Row.names").iloc[:, 1])
ad3_exp_mir = pd.DataFrame(ad3_trial_mirna.set_index("Row.names").iloc[:, 1])
eigth_exp_mir = pd.DataFrame(eight_trial_mirna.set_index("Row.names").iloc[:, 1])

# %%
#preprocess the datatables
def get_network(df1, df2, df3, networks, label, label2, label3, mrna=None):
    
    """function for merged table with all three cell lines"""
    zelllines = ["AD2", "AD3", "840"]
    if mrna != None: # get the structure of the data for mRNAs
        timeline = 3 * ["0"] + 3 * ["5"] + 3 * ["9"] + 3 * ["16"] + 3 * [
            "26"
        ] + 3 * ["36"] + ["cluster"] + ["biotype"]
    else: # get the columsn of the data for miRNAs
        timeline = 3 * ["0"] + 3 * ["5"] + 3 * ["9"] + 3 * ["16"] + 3 * [
            "26"
        ] + 3 * ["36"] + ["cluster"]
    
    #merge datasets based on inner join
    ad2 = pd.merge(df1, networks, how="inner", left_on="Row.names",
                   right_on="Probe").set_index(label2).iloc[:, label3:].drop(
                       "Probe", axis=1)
    
    #merge dataset based on innerjoin
    ad3 = pd.merge(df2,
                   networks,
                   how="inner",
                   left_on=label,
                   right_on="Probe").set_index(label2).iloc[:, label3:].drop("Probe", axis=1)
    
    #merge AD3 clone
    eighty = pd.merge(
        df3, networks, how="inner", left_on="Row.names",
        right_on="Probe").set_index(label2).iloc[:, label3:].drop("Probe",axis=1)
    
    #set columns
    ad2.columns = timeline
    ad3.columns = timeline
    eighty.columns = timeline
    
    
    #add the zelline as feature to the table
    ad2["zelline"] = ad2.shape[0] * [zelllines[0]]
    ad3["zelline"] = ad3.shape[0] * [zelllines[1]]
    eighty["zelline"] = eighty.shape[0] * [zelllines[2]]
    
    
    #concatenate all the three tables and save this tables
    gesamt = pd.concat([ad2, ad3, eighty])
    gesamt = gesamt.loc[gesamt["cluster"] != "grey"]
    if mrna:
        gesamt.to_csv("network_analysis_all_genes_mRNA.csv")
    else:
        gesamt.to_csv("network_analyis_all_miRNAs.csv")
    return gesamt

# run the fucntion for mRNA
data_processed = get_network(ad2_trial, ad3_trial, eight_trial, networks,
                             "ensembl_gene_id_version", "external_gene_name",
                             7, True)

#run the function for miRNAs
data_processed_mirna = get_network(ad2_trial_mirna, ad3_trial_mirna,
                                   eight_trial_mirna, networks_mir,
                                   "Row.names", "Row.names", 6)

# %%
#check the table
data_processed #merged datasets and normalized vst counts overview
# Out:
#                             0          0          0          5          5  \
# external_gene_name
# TSPAN6              10.308212  10.466177  10.500113  11.277834  11.383885
# DPM1                 9.552330   9.635113   9.706650   9.431686   9.381496
# SCYL3                7.581187   7.702352   7.726485   7.972679   8.059721
# C1orf112             9.058423   8.907396   9.092522   8.776643   8.792710
# FGR                  3.475525   4.096831   3.986919   2.306598   1.058756
# ...                       ...        ...        ...        ...        ...
# AC118281.1           7.814702   7.385027   7.907616   8.375890   7.265306
# AL109627.1           6.107289   5.669154   6.001648   6.419853   6.525922
# LJII02000414.1       4.312756   4.489282   4.622192   2.344983   2.393033
# CASP8AP2             4.167477   4.210541   4.494485   5.297731   4.288384
# AC275572.1           3.214920   3.760036   2.942667   3.324603   3.086350
#
#                             5          9          9          9         16  \
# external_gene_name
# TSPAN6              11.471834  10.890828  10.966747  10.891436  10.246185
# DPM1                 9.668298   9.246506   9.401868   9.230056   8.868542
# SCYL3                7.999670   8.037174   8.224401   8.100583   8.013715
# C1orf112             8.848596   9.142043   9.142087   9.152607   8.372371
# FGR                  1.949776   1.058756   2.518895   2.045225   1.058756
# ...                       ...        ...        ...        ...        ...
# AC118281.1           7.164915   7.588837   7.488006   7.615658   7.361483
# AL109627.1           6.250340   6.315480   6.020577   6.004260   6.222643
# LJII02000414.1       3.368227   2.080894   1.032625   1.032625   2.377188
# CASP8AP2             4.738780   4.846560   4.350462   4.758971   4.330019
# AC275572.1           2.870561   3.015733   3.450646   3.612815   4.397573
#
#                     ...         16         26         26         26  \
# external_gene_name  ...
# TSPAN6              ...  10.088421  10.399233  10.707685  10.681174
# DPM1                ...   8.798230   8.570458   8.797135   8.566916
# SCYL3               ...   8.076606   7.508193   7.560468   7.576916
# C1orf112            ...   8.222111   7.171840   7.391327   7.531024
# FGR                 ...   1.058756   1.058756   1.058756   2.246803
# ...                 ...        ...        ...        ...        ...
# AC118281.1          ...   7.366535   8.117697   8.781232   8.136493
# AL109627.1          ...   6.447352   6.993960   6.640416   6.516866
# LJII02000414.1      ...   2.350482   2.909866   2.888826   3.033345
# CASP8AP2            ...   4.744091   4.232435   3.680198   3.470502
# AC275572.1          ...   3.885848   3.780207   2.151514   3.799689
#
#                            36         36         36    cluster  \
# external_gene_name
# TSPAN6              10.275045  10.404344  10.471716    magenta
# DPM1                 8.456154   8.551307   8.602269       blue
# SCYL3                7.781930   7.787908   7.633315    darkred
# C1orf112             6.665187   6.841490   6.737760      green
# FGR                  1.058756   1.058756   1.058756      brown
# ...                       ...        ...        ...        ...
# AC118281.1           7.571245   8.160942   8.236038  turquoise
# AL109627.1           7.086307   6.869253   7.380254     yellow
# LJII02000414.1       3.521267   3.575091   2.998275      brown
# CASP8AP2             3.389214   3.673455   3.519321    sienna3
# AC275572.1           4.038992   3.851270   2.472120    skyblue
#
#                            biotype zelline
# external_gene_name
# TSPAN6              protein_coding     AD2
# DPM1                protein_coding     AD2
# SCYL3               protein_coding     AD2
# C1orf112            protein_coding     AD2
# FGR                 protein_coding     AD2
# ...                            ...     ...
# AC118281.1          protein_coding     840
# AL109627.1                  lncRNA     840
# LJII02000414.1          pseudogene     840
# CASP8AP2            protein_coding     840
# AC275572.1              pseudogene     840
#
# [60099 rows x 21 columns]

# %%
# z-score the timelined expression values
from scipy import stats


def z_score_dataset(network_df):
    
    """input is the dataframe with vst counts
    output -> z-score normalization along the rows """
    stats_z = network_df.iloc[:, :-3].values.astype(float)
    stats_z = stats.zscore(stats_z, axis=1)
    stats_end = pd.DataFrame(stats_z, index=network_df.index)
    stats_end["cluster"] = network_df["cluster"].tolist()
    stats_end["zelline"] = network_df["zelline"].tolist()
    return stats_end


def z_score_dataset_mirna(network_df):
    """mirna vst counts z-scored along the rows"""
    stats_z = network_df.iloc[:, :-2].values.astype(float)
    stats_z = stats.zscore(stats_z, axis=1)
    stats_end = pd.DataFrame(stats_z, index=network_df.index)
    stats_end["cluster"] = network_df["cluster"].tolist()
    stats_end["zelline"] = network_df["zelline"].tolist()
    return stats_end


z_df = z_score_dataset(data_processed)
z_df_mir = z_score_dataset_mirna(data_processed_mirna)
z_df
# Out:
#                            0         1         2         3         4  \
# external_gene_name
# TSPAN6             -0.829195 -0.441219 -0.357871  1.552275  1.812746
# DPM1                1.121506  1.310804  1.474388  0.845628  0.730859
# SCYL3              -1.240118 -0.694748 -0.586123  0.522007  0.913791
# C1orf112            0.926698  0.757520  0.964896  0.611052  0.629049
# FGR                 1.571232  2.170030  2.064099  0.444654 -0.757981
# ...                      ...       ...       ...       ...       ...
# AC118281.1          0.105881 -0.885282  0.320213  1.400416 -1.161452
# AL109627.1         -0.765365 -1.799915 -1.014811 -0.027319  0.223138
# LJII02000414.1      1.413855  1.578620  1.702675 -0.422813 -0.377964
# CASP8AP2           -0.194449 -0.112627  0.426871  1.953051  0.035276
# AC275572.1         -0.375303  0.567329 -0.846092 -0.185636 -0.597632
#
#                            5         6         7         8         9  \
# external_gene_name
# TSPAN6              2.028755  0.601758  0.788220  0.603252 -0.981539
# DPM1                1.386687  0.422178  0.777443  0.384562 -0.442111
# SCYL3               0.643498  0.812305  1.655026  1.097713  0.706716
# C1orf112            0.691653  1.020368  1.020417  1.032203  0.158190
# FGR                 0.100759 -0.757981  0.649259  0.192750 -0.757981
# ...                      ...       ...       ...       ...       ...
# AC118281.1         -1.393031 -0.415139 -0.647733 -0.353269 -0.939594
# AL109627.1         -0.427584 -0.273770 -0.970114 -1.008643 -0.492983
# LJII02000414.1      0.532257 -0.669306 -1.647733 -1.647733 -0.392754
# CASP8AP2            0.891034  1.095819  0.153226  0.929398  0.114383
# AC275572.1         -0.970782 -0.719745  0.032321  0.312749  1.669780
#
#                           10        11        12        13        14  \
# external_gene_name
# TSPAN6             -1.109936 -1.369020 -0.605639  0.151943  0.086830
# DPM1               -0.944436 -0.602892 -1.123738 -0.605397 -1.131838
# SCYL3               0.993235  0.989790 -1.568670 -1.333376 -1.259341
# C1orf112            0.093506 -0.010129 -1.186632 -0.940765 -0.784277
# FGR                -0.757981 -0.757981 -0.757981 -0.757981  0.387025
# ...                      ...       ...       ...       ...       ...
# AC118281.1         -0.618193 -0.927939  0.804822  2.335449  0.848182
# AL109627.1         -0.324414  0.037613  1.328298  0.493489  0.201755
# LJII02000414.1     -1.647733 -0.417680  0.104435  0.084796  0.219686
# CASP8AP2            0.749133  0.901127 -0.071028 -1.120287 -1.518712
# AC275572.1          1.189171  0.784888  0.602210 -2.214182  0.635899
#
#                           15        16        17    cluster zelline
# external_gene_name
# TSPAN6             -0.910656 -0.593088 -0.427616    magenta     AD2
# DPM1               -1.385117 -1.167531 -1.050995       blue     AD2
# SCYL3              -0.336561 -0.309654 -1.005489    darkred     AD2
# C1orf112           -1.754179 -1.556686 -1.672884      green     AD2
# FGR                -0.757981 -0.757981 -0.757981      brown     AD2
# ...                      ...       ...       ...        ...     ...
# AC118281.1         -0.455720  0.904578  1.077809  turquoise     840
# AL109627.1          1.546354  1.033831  2.240438     yellow     840
# LJII02000414.1      0.675100  0.725338  0.186953      brown     840
# CASP8AP2           -1.673160 -1.133099 -1.425956    sienna3     840
# AC275572.1          1.049710  0.725094 -1.659779    skyblue     840
#
# [60099 rows x 20 columns]

# %%
z_df_mir["cluster"].value_counts() # data set overview
# Out:
# turquoise       561
# blue            456
# brown           432
# yellow          378
# green           354
# red             339
# black           318
# pink            216
# magenta         213
# purple          195
# greenyellow     189
# tan             171
# salmon          168
# cyan            126
# midnightblue     99
# grey60           81
# lightcyan        81
# Name: cluster, dtype: int64

# %%
def mean_value(df):
    """get the mean value for each of the days as well as the standard error of the mean
    table for miRNA and mRNA z-scored as input"""
    network_mean = pd.DataFrame()
    network_mean["0"] = df.iloc[:, :2].mean(axis=1)
    network_mean["5"] = df.iloc[:, 2:5].mean(axis=1)
    network_mean["9"] = df.iloc[:, 5:8].mean(axis=1)
    network_mean["16"] = df.iloc[:, 8:11].mean(axis=1)
    network_mean["26"] = df.iloc[:, 11:14].mean(axis=1)
    network_mean["36"] = df.iloc[:, 14:17].mean(axis=1)
    network_mean["0_sem"] = df.iloc[:, :2].sem(axis=1)
    network_mean["5_sem"] = df.iloc[:, 2:5].sem(axis=1)
    network_mean["9_sem"] = df.iloc[:, 5:8].sem(axis=1)
    network_mean["16_sem"] = df.iloc[:, 8:11].sem(axis=1)
    network_mean["26_sem"] = df.iloc[:, 11:14].sem(axis=1)
    network_mean["36_sem"] = df.iloc[:, 14:17].sem(axis=1)
    network_mean["cluster"] = df["cluster"].tolist()
    network_mean["zelline"] = df["zelline"].tolist()
    return network_mean

# %%
def mean_value_hierach(df):
    """get the mean value for each of the days as well as the standard error of the mean
    table for miRNA and mRNA z-scored as input"""
    network_mean = pd.DataFrame()
    network_mean["0"] = df.iloc[:, :2].mean(axis=1)
    network_mean["5"] = df.iloc[:, 2:5].mean(axis=1)
    network_mean["9"] = df.iloc[:, 5:8].mean(axis=1)
    network_mean["16"] = df.iloc[:, 8:11].mean(axis=1)
    network_mean["26"] = df.iloc[:, 11:14].mean(axis=1)
    network_mean["36"] = df.iloc[:, 14:17].mean(axis=1)
    network_mean["0_sem"] = df.iloc[:, :2].sem(axis=1)
    network_mean["5_sem"] = df.iloc[:, 2:5].sem(axis=1)
    network_mean["9_sem"] = df.iloc[:, 5:8].sem(axis=1)
    network_mean["16_sem"] = df.iloc[:, 8:11].sem(axis=1)
    network_mean["26_sem"] = df.iloc[:, 11:14].sem(axis=1)
    network_mean["36_sem"] = df.iloc[:, 14:17].sem(axis=1)
    network_mean["cluster"] = df["clustering"].tolist()
    network_mean["hierachical_cluster"] = df["hierachical_cluster"].tolist()
    return network_mean

# %%
meaned_df = mean_value(z_df)
meaned_df_mir = mean_value(z_df_mir)
meaned_df
# Out:
#                            0         5         9        16        26  \
# external_gene_name
# TSPAN6             -0.635207  1.002384  1.139578 -0.496075 -0.607572
# DPM1                1.216155  1.016958  0.862103 -0.333995 -0.777342
# SCYL3              -0.967433  0.283225  1.036943  0.932555 -0.637419
# C1orf112            0.842109  0.734999  0.910813  0.427966 -0.712509
# FGR                 1.870631  0.583591 -0.002654 -0.441071 -0.757981
# ...                      ...       ...       ...       ...       ...
# AC118281.1         -0.389700  0.186392 -0.818634 -0.637019  0.737444
# AL109627.1         -1.282640 -0.272997 -0.557156 -0.608680  0.619800
# LJII02000414.1      1.496238  0.300633 -0.594927 -1.229407 -0.076150
# CASP8AP2           -0.153538  0.805066  0.713360  0.597638 -0.096729
# AC275572.1          0.096013 -0.543120 -0.552735  1.057233 -0.275695
#
#                           36     0_sem     5_sem     9_sem    16_sem  \
# external_gene_name
# TSPAN6             -0.472305  0.193988  0.684271  0.447835  0.550911
# DPM1               -1.228162  0.094649  0.231102  0.281629  0.387439
# SCYL3              -0.635186  0.272685  0.449147  0.312860  0.116878
# C1orf112           -1.365048  0.084589  0.115066  0.109580  0.302695
# FGR                -0.376312  0.299399  0.817621  0.409513  0.316910
# ...                      ...       ...       ...       ...       ...
# AC118281.1          0.432347  0.495581  0.742568  0.294943  0.169519
# AL109627.1          0.927314  0.517275  0.377888  0.211199  0.205817
# LJII02000414.1      0.540042  0.082382  0.701141  0.630407  0.418327
# CASP8AP2           -1.441657  0.040911  0.585018  0.286238  0.247168
# AC275572.1          0.803567  0.471316  0.192596  0.301371  0.397257
#
#                       26_sem    36_sem    cluster zelline
# external_gene_name
# TSPAN6              0.439065  0.294214    magenta     AD2
# DPM1                0.173199  0.079151       blue     AD2
# SCYL3               0.816435  0.312175    darkred     AD2
# C1orf112            0.358290  0.295929      green     AD2
# FGR                 0.000000  0.381668      brown     AD2
# ...                      ...       ...        ...     ...
# AC118281.1          0.942661  0.444332  turquoise     840
# AL109627.1          0.377903  0.391789     yellow     840
# LJII02000414.1      0.170859  0.160833      brown     840
# CASP8AP2            0.583673  0.160592    sienna3     840
# AC275572.1          0.970677  0.125736    skyblue     840
#
# [60099 rows x 14 columns]

# %%
def mean_curve(zs_df):
    
    """draw the curves 
    input -> z-scored mean dataframe
    output -> meaned curves drawed"""
    # select based on each cell line
    ad2 = zs_df.loc[zs_df["zelline"] == "AD2"]
    ad3 = zs_df.loc[zs_df["zelline"] == "AD3"]
    eighty = zs_df.loc[zs_df["zelline"] == "840"]
    columns = ["0", "5", "10", "16", "26", "36"]
    
    for i in set(zs_df["cluster"].tolist()): # go through each cluster
        pr_ad2 = ad2.loc[ad2["cluster"] == i] #subset based on cluster
        pr_ad3 = ad3.loc[ad3["cluster"] == i]
        pr_eighty = eighty.loc[eighty["cluster"] == i]
        
        ad2_mean = pd.DataFrame()
        ad3_mean = pd.DataFrame()
        eighty_mean = pd.DataFrame()
        
        ad2_mean["mean"] = pr_ad2.iloc[:, :6].mean() # get the mean of the cluster and the sem of the cluster for all genes
        ad3_mean["mean"] = pr_ad3.iloc[:, :6].mean()
        eighty_mean["mean"] = pr_eighty.iloc[:, :6].mean()
        ad2_mean["sem"] = pr_ad2.iloc[:, :6].sem()
        ad3_mean["sem"] = pr_ad3.iloc[:, :6].sem()
        eighty_mean["sem"] = pr_eighty.iloc[:, :6].sem()
        
        #draw the plots for the analysis 
        fig, ax = plt.subplots()
        sns.despine()
        ax.plot(eighty_mean.iloc[:, :1], color="blue")
        plt.fill_between(eighty_mean.index,
                         eighty_mean["mean"] - eighty_mean["sem"],
                         eighty_mean["mean"] + eighty_mean["sem"],
                         alpha=0.5,
                         color="blue")
        ax.plot(ad2_mean.iloc[:, :1], color="green")
        plt.fill_between(ad2_mean.index,
                         ad2_mean["mean"] - ad2_mean["sem"],
                         ad2_mean["mean"] + ad2_mean["sem"],
                         alpha=0.5,
                         color="green")
        ax.plot(ad3_mean.iloc[:, :1], color="red")
        plt.fill_between(ad3_mean.index,
                         ad3_mean["mean"] - ad3_mean["sem"],
                         ad3_mean["mean"] + ad3_mean["sem"],
                         alpha=0.5,
                         color="red")
        plt.title(str(i))
        
        #save the plots
        #plt.savefig(str(i) + "_mirna_cluster_ad2_ad3_840_curve.svg",
        #            quality=90,
        #            transparent=True,
        #            dpi=600,
        #            bbox_inches="tight")
    return ad2 # control if this worked correctly

# %%
# make cluster ready for g-profiling and return data
go_profiling = mean_curve(meaned_df)
go_profiling_end = go_profiling.reset_index()
go_profiling_end = go_profiling_end.dropna().set_index("external_gene_name")
# Out:
# /Users/maximilianzeidler/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:29: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# /Users/maximilianzeidler/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:29: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# /Users/maximilianzeidler/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:29: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# /Users/maximilianzeidler/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:29: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# /Users/maximilianzeidler/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:29: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# /Users/maximilianzeidler/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:29: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# /Users/maximilianzeidler/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:29: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# /Users/maximilianzeidler/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:29: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# /Users/maximilianzeidler/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:29: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# /Users/maximilianzeidler/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:29: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# /Users/maximilianzeidler/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:29: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# /Users/maximilianzeidler/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:29: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# /Users/maximilianzeidler/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:29: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# /Users/maximilianzeidler/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:29: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# /Users/maximilianzeidler/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:29: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# /Users/maximilianzeidler/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:29: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# /Users/maximilianzeidler/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:29: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# /Users/maximilianzeidler/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:29: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# /Users/maximilianzeidler/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:29: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# /Users/maximilianzeidler/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:29: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# /Users/maximilianzeidler/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:29: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# /Users/maximilianzeidler/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:29: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# /Users/maximilianzeidler/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:29: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# /Users/maximilianzeidler/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:29: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# /Users/maximilianzeidler/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:29: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# /Users/maximilianzeidler/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:29: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# /Users/maximilianzeidler/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:29: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# /Users/maximilianzeidler/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:29: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# /Users/maximilianzeidler/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:29: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).

# %% [raw]
# # Get the miRNA curves

# %%
#draw the curves for each of the meaned modules
mirna_curves = mean_curve(meaned_df_mir)

# %%
# get the enriched genes pathways
import requests

def mirna_analysis_go_div(diana_df, species, cluster=None):
    # diana_dictionary == output von diana_only mirnas bzw. eigener DataFrame,
    # col_name is der Name der Column, die die Gene beinhaltet
    # sources = sind die sources die man gerne erhalten möchte als Liste bspw. ["GO"] wären alle Termen
    # ["GO:BP"] wäre einzig und allein Biological Process
    # KEGG ist ein optionaler parameter der angegeben kann wenn man auch an KEGG Pathways interessiert ist
    go_profiler = {}
    df_go_end = pd.DataFrame()
    if cluster != None:
        for i in sorted(set(diana_df[cluster].tolist())):
            diana_df_end = diana_df.loc[diana_df[cluster] == i]
            protein_list = diana_df_end.index.tolist()
            print(len(protein_list))

            r = requests.post(
                url='https://biit.cs.ut.ee/gprofiler/api/gost/profile/',
                json={
                    'organism': species,
                    'query': protein_list,
                    'sources': ["GO:BP", "GO:MF", "GO:CC", "KEGG"],
                },
                headers={'User-Agent': 'FullPythonRequest'})
            try:
                data = r.json()["result"]
                parents_list = []
                go_list = []
                p_value = []
                desc_value = []
                source_list = []
                for n in data:
                    go_list.append(n["native"])
                    for t in n["parents"]:
                        parents_list.append(t)
                end_list = [i for i in go_list if i not in parents_list]
                for m in data:
                    if m["native"] in end_list:
                        p_value.append(m["p_value"])
                for l in data:
                    if l["native"] in end_list:
                        desc_value.append(l["name"])
                for l in data:
                    if l["native"] in end_list:
                        source_list.append(l["source"])
                go_profiler.update({
                    "p-value": p_value,
                    "go-terms": end_list,
                    "description": desc_value,
                    "source": source_list
                })
                df_go = pd.DataFrame(
                    columns=["go-terms", "description", "source", "p-value"])
                df_go["go-terms"] = list(end_list)
                df_go["description"] = desc_value
                df_go["source"] = source_list
                df_go["p-value"] = p_value
                df_go["cluster"] = df_go.shape[0] * [str(i)]
                df_go_end = df_go_end.append(df_go)

            except KeyError as e:
                pass

    #df_go_end.to_excel("signed_go_enrichment_analysis_filtered.xlsx")
    return (df_go_end)

# %%
#run the function an generate gprofiler output
mirna_analysis_go_div(go_profiling_end, "hsapiens", "cluster") #mRNA enrichment per cluster
# Out:
# 72
# 851
# 2249
# 2202
# 94
# 341
# 230
# 208
# 153
# 162
# 194
# 95
# 236
# 66
# 214
# 96
# 1122
# 420
# 283
# 102
# 288
# 108
# 268
# 108
# 250
# 478
# 112
# 321
# 197
# 113
# 169
# 511
# 127
# 53
# 432
# 1048
# 245
# 173
# 405
# 150
# 181
# 140
# 172
# 407
# 2440
# 163
# 188
# 1250
# 146
#       go-terms                                   description source   p-value  \
# 0   GO:0005802                           trans-Golgi network  GO:CC  0.001929
# 1   KEGG:04141   Protein processing in endoplasmic reticulum   KEGG  0.004862
# 2   GO:0098588                bounding membrane of organelle  GO:CC  0.016878
# 3   GO:0012505                           endomembrane system  GO:CC  0.035516
# 4   GO:0030135                                coated vesicle  GO:CC  0.048262
# ..         ...                                           ...    ...       ...
# 5   GO:0043232  intracellular non-membrane-bounded organelle  GO:CC  0.018283
# 6   GO:0003677                                   DNA binding  GO:MF  0.018853
# 7   GO:1901576        organic substance biosynthetic process  GO:BP  0.043093
# 8   GO:0006259                         DNA metabolic process  GO:BP  0.046301
# 9   GO:0006397                               mRNA processing  GO:BP  0.049188
#
#         cluster
# 0       bisque4
# 1       bisque4
# 2       bisque4
# 3       bisque4
# 4       bisque4
# ..          ...
# 5   yellowgreen
# 2                    A2M        yellow -1.454476 -1.975559 -1.736869
# 3                A2M-AS1        yellow -0.746698 -0.752394 -1.017090
# 4                  A2ML1         brown  2.204572  2.186100  2.146390
# ...                  ...           ...       ...       ...       ...
# 20018               ZXDB        yellow  0.589592  0.524103  0.341769
# 20019               ZXDC  midnightblue -0.186577 -0.200412 -1.001431
# 20020             ZYG11A         brown  1.993787  1.995876  2.042825
# 20021             ZYG11B       skyblue -1.154855 -1.152607 -0.867057
# 20022              ZZEF1           red -1.328855 -1.509328 -1.384237
#
#               3         4         5         6         7         8         9  \
# 0     -0.778902 -0.638063 -1.096838 -0.639447 -0.546316 -0.478661  0.649008
# 1     -0.533092 -0.264159 -0.835172  0.189876 -0.083358  0.026046  0.890990
# 2     -0.772198 -0.594543 -0.634339  0.478806  0.519499  0.401473 -0.214731
# 3     -0.031970  0.604756  0.383635 -0.636846 -0.970670 -0.670532 -0.614501
# 4     -0.413160 -0.412432 -0.421141 -0.505915 -0.525258 -0.529161 -0.471448
# ...         ...       ...       ...       ...       ...       ...       ...
# 20018 -0.681105  0.597626  0.178377 -0.557012 -0.505645 -0.701777 -1.359185
# 20019  1.158942  0.658447  0.451850  1.036208  1.269564  0.817147  0.749494
# 20020  0.030050  0.335311  0.232033 -0.399767 -0.477731 -0.560272  0.106880
# 20021 -1.243610 -0.332531 -0.318819  0.229107 -0.289278  0.051845  0.245225
# 20022 -1.249561 -0.959768 -0.983875  0.446528  0.015541  0.337665  0.683205
#
#              10        11        12        13        14        15        16  \
# 0      0.363506  0.441897  0.636158  0.515317  0.194895  1.236746  1.212811
# 1      0.681018  1.036756  0.411738  0.911719  0.659412  0.470887  0.958745
# 2      0.071434 -0.025554  0.832896  0.839849  0.988033  1.046751  1.112515
# 3     -0.491060 -0.460158  0.483253  0.331966  0.488677  1.228579  1.613121
# 4     -0.530541 -0.636931 -0.056110 -0.376062 -0.428660 -0.331046 -0.410876
# ...         ...       ...       ...       ...       ...       ...       ...
# 20018 -0.601766 -1.280026  0.129327  0.497222 -0.509675  1.359296  1.044406
# 20019 -0.304080  0.249330 -0.210573 -0.153240 -0.615083 -1.537085 -0.792631
# 20020 -0.507826 -0.478926 -0.611067 -0.715742 -1.035652 -0.468974 -0.636379
# 20021  1.433984  0.369583 -0.009661 -0.312149 -0.032464  1.465256  1.169481
# 20022  0.451534  0.704988  0.763314  0.663924  0.664831  0.887131  1.050629
#
#              17
# 0      1.764265
# 1      0.687251
# 2      1.117014
# 3      1.257931
# 4     -0.488322
# ...         ...
# 20018  0.934474
# 20019 -1.389869
# 20020 -0.844428
# 20021  0.748550
# 20022  0.746332
#
# [20023 rows x 20 columns]

# %%
from scipy.spatial import distance
from scipy.cluster import hierarchy
from scipy.cluster.hierarchy import ward, fcluster
pfad = "/home/physiologie/Desktop/iPSC/mRNA/RawData/analysis/counts/Network_construction/"

# cluster using hierachical clustering average method
def hierachical_clustering(df, threshold_cluster, label,label2, pfad):
    """
        defines the hierachical clustering of the data
        threshold_mRNA : threshold mRNA clustering after visualization
        threshold_miRNA : threhsold miRNA clustering after visualization
        """
    mRNA_correlation = np.asarray(df)
    #mRNA_correlation = stats.zscore(mRNA_correlation,axis = 1)

    # Define the hierachical linkage for rows and columns mRNA

    row_linkage_mRNA = hierarchy.linkage(distance.pdist(mRNA_correlation),method='average')

    col_linkage_mRNA = hierarchy.linkage(distance.pdist(mRNA_correlation),method='average')

    #get the cluster for miRNAs and mRNAs

    hierarchical_cluster_mRNA = fcluster(row_linkage_mRNA, threshold_cluster,"distance")

    #draw the dendograms

    fig, ax = plt.subplots(figsize=(15, 8))
    dn_mRNA = hierarchy.dendrogram(row_linkage_mRNA)
    plt.axhline(y=threshold_cluster, color='r', linestyle='-')
    plt.savefig(label2 + ".svg", quality=90, dpi=600, transparent=True)

    #extract clusters and assign to all the tables

    all_mrna = df

    all_mrna["hierachical_cluster"] = hierarchical_cluster_mRNA

    #determine the highest cluster number for further investigation

    max_clust_mRNA = all_mrna["hierachical_cluster"].max()
    print(max_clust_mRNA)

    #safe tables to previously specified path

    #all_mrna.to_csv(label)
    return (all_mrna, hierarchical_cluster_mRNA)


hierachical_cluster = hierachical_clustering(aggregated_z_df, 3.25, "save_path","save_path", pfad)
# Out:
# 6

# %%
#get only clusters and genes
aggregated_z_df_cluster = aggregated_z_df.iloc[:, -1:]
aggregated_z_df_cluster = aggregated_z_df_cluster.reset_index()

# add the hierachical clustering to the gene names
gesamt = pd.merge(genes_cluster,
                  aggregated_z_df_cluster,
                  how="inner",
                  left_on="cluster",
                  right_on="cluster")
gesamt = gesamt.set_index(["external_gene_name", "cluster"])
gesamt
# Out:
#                                    0         1         2         3         4  \
# external_gene_name cluster
# A1BG               bisque4 -1.009933 -0.926393 -0.900050 -0.778902 -0.638063
# ABHD2              bisque4 -0.792052 -0.788651 -0.791197 -1.252975 -0.995066
# AC003681.1         bisque4  0.621397  0.473684 -0.072030 -0.607909  0.841732
# AC067852.3         bisque4 -1.395012 -0.737278 -1.249986 -1.344368 -0.221268
# AC087163.2         bisque4 -0.494312 -0.663351 -0.380047 -0.292224 -0.513602
# ...                              ...       ...       ...       ...       ...
# TRIM35             brown4   0.564172  0.384568  1.112505 -1.615006 -1.021456
# UNC13B             brown4   0.854482  0.638213  0.796213 -2.168336 -0.960272
# USH1G              brown4   0.838723  1.038528  0.816323 -1.182848 -1.109770
# WTAPP1             brown4   0.238935 -0.034644  0.654800 -0.101023  0.309611
# ZNF488             brown4   1.179074  1.107315  1.156010 -1.481935 -1.461760
#
#                                    5         6         7         8         9  \
# external_gene_name cluster
# A1BG               bisque4 -1.096838 -0.639447 -0.546316 -0.478661  0.649008
# ABHD2              bisque4 -0.994503 -0.581671 -0.938591 -0.937914  0.389112
# AC003681.1         bisque4  0.002464 -1.190315 -1.248332 -1.335493 -0.258653
# AC067852.3         bisque4 -0.578643  0.241014 -0.224692  0.230000  0.503600
# AC087163.2         bisque4  0.350780  0.512961 -0.017490 -0.034084  0.281627
# ...                              ...       ...       ...       ...       ...
# TRIM35             brown4  -0.815787 -0.017079 -0.442807 -0.263254  0.847579
# UNC13B             brown4  -0.645735 -0.286789 -0.876878 -0.385156  0.919516
# USH1G              brown4  -1.283811 -0.871899 -0.965883 -1.201457  1.459558
# WTAPP1             brown4  -0.003858 -0.443398 -1.180675 -0.506746  1.532117
# ZNF488             brown4  -1.661481 -0.367137 -0.231360 -0.190368  1.290601
#
#                                   10        11        12        13        14  \
# external_gene_name cluster
# A1BG               bisque4  0.363506  0.441897  0.636158  0.515317  0.194895
# ABHD2              bisque4  0.976313  0.422731  0.885360  0.835760  1.016799
# AC003681.1         bisque4  0.310259  0.504362  0.190671 -0.788582  0.167896
# AC067852.3         bisque4  1.174592  0.399291  0.318573 -0.400759 -0.518624
# AC087163.2         bisque4  0.715792  0.375079 -0.002726 -1.943826 -0.343309
# ...                              ...       ...       ...       ...       ...
# TRIM35             brown4   1.620755  0.940745 -0.464627 -0.775948 -0.887494
# UNC13B             brown4   0.788105  0.770604  0.451806 -0.300984  0.030608
# USH1G              brown4   1.295456  1.491316 -0.219544 -0.017658 -0.183792
# WTAPP1             brown4   2.107363  1.306421 -1.180675  0.125305 -0.487195
# ZNF488             brown4   1.348868  1.325945 -0.172538 -0.021612 -0.027961
#
#                                   15        16        17  hierachical_cluster
# external_gene_name cluster
# A1BG               bisque4  1.236746  1.212811  1.764265                    3
# ABHD2              bisque4  1.215740  1.281514  1.049289                    3
# AC003681.1         bisque4  1.060799  0.956414  0.371635                    3
# AC067852.3         bisque4  1.286129  1.419799  1.097633                    3
# AC087163.2         bisque4  0.483261  1.013327  0.952143                    3
# ...                              ...       ...       ...                  ...
# TRIM35             brown4   0.174651  0.806624 -0.148142                    4
# UNC13B             brown4   0.384496  0.077900 -0.087794                    4
# USH1G              brown4  -0.024233 -0.004283  0.125275                    4
# WTAPP1             brown4  -1.180675 -0.896226 -0.259435                    4
# ZNF488             brown4  -0.473600 -0.761179 -0.556885                    4
#
# [20023 rows x 19 columns]

# %%
# try a different approach with k-means or another cluster algorithm
def svd_scatter(df):
    """singular value decomposition of the gene expression values,
    can be used as sanitiy check for the clustering:
    colored using the hierachical clustering and drawn as a clock
    df-> gene expression/miRNA expression dataset"""
    u, s, vh = np.linalg.svd(df.iloc[:, :-1].values)
    labels = ['SV' + str(i) for i in range(1, 3)]
    svd_df = pd.DataFrame(u[:, 0:2], columns=labels)
    svd_df["cluster"] = df["hierachical_cluster"].tolist()
    ax = plt.subplots(figsize=(12, 12))
    sns.despine()
    sns.scatterplot(data=svd_df,
                    x="SV1",
                    y="SV2",
                    hue="cluster",
                    legend="full",
                    palette="tab10",
                    linewidth=0,
                    s=10,
                    alpha=0.7)
    plt.xlabel("SVD1")
    plt.ylabel("SVD2")
    plt.title("iPSC-derived Nociceptor Differentiation Clock")
    plt.savefig(
        "miRNA_power16_ipsc_derived_nociceptor_differentiation_clock.svg",
        quality=90,
        transparent=True,
        dpi=600,
        bbox_inches="tight")


svd_scatter(gesamt)

# %%
#draw the clustered modules

gesamt_line = gesamt.reset_index().set_index("external_gene_name")
gesamt_line.info()
gesamt_line.columns = [
    "cluster", "0", "0", "0", "5", "5", "5", "9", "9", "9", "16", "16", "16",
    "26", "26", "26", "36", "36", "36", "hierachical_cluster"
]
gesamt_line["clustering"] = gesamt_line["cluster"]
gesamt_line = gesamt_line.drop("cluster", axis=1)
svd_mean = mean_value_hierach(gesamt_line) 
print(svd_mean)
mean_curves = svd_mean.groupby(["cluster"]).agg("mean")
color = ["blue", "orange", "red", "brown", "purple", "green", "skyblue"]
for i, t in zip(set(gesamt_line["hierachical_cluster"].tolist()), color):
    # get the module trajectories
    clustered = mean_curves[mean_curves["hierachical_cluster"] == i]
    #draw the plot of all corresponding module trajectories per cluster
    fig, ax = plt.subplots()
    sns.despine()
    plotting = clustered.iloc[:, 0:6].T
    ax.plot(plotting, c=t)
    plt.title("Super-cluster number %s" % (str(i)))
    plt.ylabel("z-scored standardized gene expression", fontsize=12)
    plt.xlabel("Differentiation Days", fontsize=12)
    
    
    #plt.savefig("super_cluster_" + str(i) + ".svg",
    #            dpi=600,
    #            transparent=True,
    #            quality=90,
    #            bbox_inches="tight")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20023 entries, A1BG to ZNF488
# Data columns (total 20 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   cluster              20023 non-null  object
#  1   0                    20023 non-null  float64
#  2   1                    20023 non-null  float64
#  3   2                    20023 non-null  float64
#  4   3                    20023 non-null  float64
#  5   4                    20023 non-null  float64
#  6   5                    20023 non-null  float64
#  7   6                    20023 non-null  float64
#  8   7                    20023 non-null  float64
#  9   8                    20023 non-null  float64
#  10  9                    20023 non-null  float64
#  11  10                   20023 non-null  float64
#  12  11                   20023 non-null  float64
#  13  12                   20023 non-null  float64
#  14  13                   20023 non-null  float64
#  15  14                   20023 non-null  float64
#  16  15                   20023 non-null  float64
#  17  16                   20023 non-null  float64
#  18  17                   20023 non-null  float64
#  19  hierachical_cluster  20023 non-null  int32
# dtypes: float64(18), int32(1), object(1)
# memory usage: 3.1+ MB
#                            0         5         9        16        26  \
# external_gene_name
# A1BG               -0.968163 -0.772338 -0.760867  0.177951  0.531124
# ABHD2              -0.790352 -1.013079 -0.838255  0.142504  0.714617
# AC003681.1          0.547540  0.053931 -0.812061 -0.427962 -0.031183
# AC067852.3         -1.066145 -0.938541 -0.187440  0.636064  0.105701
# AC087163.2         -0.578831 -0.395291  0.282084  0.321112 -0.523825
# ...                      ...       ...       ...       ...       ...
# TRIM35              0.474370 -0.507986 -0.425224  0.735027 -0.099943
# UNC13B              0.746348 -0.777465 -0.603134  0.440822  0.307142
# USH1G               0.938625 -0.492098 -1.040531  0.517852  0.418038
# WTAPP1              0.102145  0.287796 -0.542644  1.044244  0.083684
# ZNF488              1.143195 -0.595895 -0.753326  0.816367  0.377265
#
#                           36     0_sem     5_sem     9_sem    16_sem  \
# external_gene_name
# A1BG                0.881484  0.041770  0.075700  0.170123  0.338493
# ABHD2               1.171351  0.001700  0.133608  0.129303  0.566179
# AC003681.1          0.728370  0.073856  0.423188  0.407606  0.482571
# AC067852.3          0.729101  0.328867  0.359670  0.237347  0.280609
# AC087163.2          0.384427  0.084520  0.064359  0.156933  0.217369
# ...                      ...       ...       ...       ...       ...
# TRIM35              0.031260  0.089802  0.828164  0.230735  0.546770
# UNC13B              0.164335  0.108134  0.860659  0.171670  0.414727
# USH1G              -0.070769  0.099902  0.654551  0.124629  0.860959
# WTAPP1             -0.854699  0.136790  0.218460  0.343323  0.793075
# ZNF488             -0.420913  0.035880  0.875972  0.455766  0.503649
#
#                       26_sem    36_sem  cluster  hierachical_cluster
# external_gene_name
# A1BG                0.056633  0.343364  bisque4                    3
# ABHD2               0.146644  0.079574  bisque4                    3
# AC003681.1          0.389376  0.281852  bisque4                    3
# AC067852.3          0.254300  0.625055  bisque4                    3
# AC087163.2          0.718329  0.394733  bisque4                    3
# ...                      ...       ...      ...                  ...
# TRIM35              0.528048  0.494277   brown4                    4
# UNC13B              0.317685  0.110924   brown4                    4
# USH1G               0.539795  0.056804   brown4                    4
# WTAPP1              0.718264  0.201264   brown4                    4
# ZNF488              0.476337  0.213295   brown4                    4
#
# [20023 rows x 14 columns]

# %%
#save results to with hierachical clustering and module affiliation
gesamt = gesamt.reset_index().drop_duplicates("external_gene_name")
gesamt.to_csv("Supercluster_iPSC_network_mRNA_all_zelllines.csv")

# %%
# miRNA analysis according to gene expression analysis
aggregated_z_mir = z_df_mir.reset_index()
aggregated_z_mir = aggregated_z_mir.groupby(["cluster"],as_index=True).agg("mean")

#get the clusters 
mir_cluster = z_df_mir.groupby(["Row.names", "cluster"],as_index=True).agg("mean")
mir_cluster = mir_cluster.reset_index()
mir_cluster
# Out:
#             Row.names    cluster         0         1         2         3  \
# 0     hsa-let-7a-2-3p      green -0.711736 -0.711736 -0.711736 -0.711736
# 1       hsa-let-7a-3p  turquoise  1.416244  1.170174  1.377321 -0.260400
# 2       hsa-let-7c-3p      brown -0.672065 -1.022135 -1.022135 -1.022135
# 3       hsa-let-7c-5p      green -0.560707 -0.623310 -0.539775 -1.071559
# 4       hsa-let-7d-3p      green -0.512757  0.015488 -0.433397 -0.602403
# ...               ...        ...       ...       ...       ...       ...
# 1454     hsa-miR-9985      green -1.523720 -1.734327 -1.550091 -0.777392
# 1455   hsa-miR-99a-3p    magenta -1.449182 -1.449182 -1.039622 -1.044159
# 1456   hsa-miR-99a-5p       pink -1.387617 -1.401427 -1.279518 -1.416952
# 1457   hsa-miR-99b-3p       blue -0.227814 -0.263632  0.064404 -0.487878
# 1458   hsa-miR-99b-5p       blue -0.701288 -0.598267 -0.398772 -0.457365
#
#              4         5         6         7         8         9        10  \
# 0    -0.711736 -0.711736 -0.711736 -0.711736 -0.711736 -0.711736  0.004884
# 1     0.046243 -0.976069 -0.976069 -0.976069 -0.976069 -0.254896 -0.544888
# 2    -1.022135 -0.765774 -0.546308 -1.022135 -1.022135  0.376021  0.167223
# 3    -1.149861 -1.068681 -1.099902 -0.911701 -0.952806  0.109937  0.099396
# 4    -1.094916 -0.735234 -0.678704 -0.906022 -0.860724 -0.234374 -0.371493
# ...        ...       ...       ...       ...       ...       ...       ...
# 1454 -0.739837 -0.681852  0.025638  0.011136 -0.090390  0.063818  0.277343
# 1455 -1.449182 -1.449182  0.949637  0.610512  0.732665  0.901544  0.784132
# 1456 -1.466510 -1.370237  0.379006  0.304528  0.337033  0.867052  0.794427
# 1457 -0.692723 -0.628886 -1.753255 -1.480711 -1.492618  0.226206  0.368173
# 1458 -0.563686 -0.572047 -1.585228 -1.398853 -1.336931  0.226732  0.325340
#
#             11        12        13        14        15        16        17
# 0    -0.129368  0.689224  1.059053  0.888609  1.475432  1.527488  1.602043
# 1    -0.751493 -0.606949 -0.032232 -0.520974  1.055045  0.773273  1.037811
# 2     0.140834  1.257946  0.929124  1.045601  1.499181  1.371299  1.329727
# 3     0.098706  1.059015  0.991945  1.219460  1.432786  1.472913  1.494143
# 4    -0.271278  0.263901  0.147158  0.273526  1.976836  1.935746  2.088648
# ...        ...       ...       ...       ...       ...       ...       ...
# 1454  0.115885  0.721103  0.800785  0.642982  1.522731  1.500038  1.416151
# 1455  0.861770  0.674820  0.474954  0.506848  0.611247  0.448283  0.324098
# 1456  0.779356  0.867244  0.845520  0.856696  0.812287  0.685098  0.794013
# 1457  0.654995  0.910006  0.778824  1.042905  0.841354  1.190614  0.950037
# 1458  0.558498  0.847672  0.832209  1.101087  1.041587  1.467016  1.212295
#
# [1459 rows x 20 columns]

# %%
#miRNA clustering
hierachical_clustering(aggregated_z_mir,2.0,"miRNA.csv","supercluster", pfad)[1]
# Out:
# 5
# array([3, 1, 1, 3, 1, 5, 4, 3, 2, 3, 1, 3, 4, 2, 5, 3, 3], dtype=int32)

# %%
#same clsutering procedure for miRNAs as for mRNAs
aggregated_z_mir_cluster = aggregated_z_mir.iloc[:, -1:]
aggregated_z_mir_cluster = aggregated_z_mir_cluster.reset_index()

## merge the miRNA clusters and the hierachical clusters determined
mir_clustering = pd.merge(mir_cluster,
                          aggregated_z_mir_cluster,
                          how="inner",
                          left_on="cluster",
                          right_on="cluster")
mir_clustering = mir_clustering.set_index(["Row.names", "cluster"])
#mir_clustering.to_csv("miR_superclustering.csv")
svd_scatter(mir_clustering)

# %%
#get mirna hierachical cluster plots
mir_line = mir_clustering.reset_index().set_index("Row.names")
mir_line["clustering"] = mir_line["cluster"]
mir_line = mir_line.drop(["cluster"], axis=1)
mir_line.columns = [
    "0", "0", "0", "5", "5", "5", "9", "9", "9", "16", "16", "16", "26", "26",
    "26", "36", "36", "36", "hierachical_cluster", "clustering"]
mir_mean = mean_value_hierach(mir_line)
mir_draw = mir_mean.groupby(["cluster"]).agg("mean")
color = ["blue", "orange", "red", "brown", "purple"]

#go through the individual clusters
for i, t in zip(set(mir_line["hierachical_cluster"].tolist()), color):
    mir_clustered = mir_draw[mir_draw["hierachical_cluster"] == i]
    fig, ax = plt.subplots()
    sns.despine()
    plotting = mir_clustered.iloc[:, 0:6].T
    ax.plot(plotting, c=t)
    plt.title("miRNA_Super-cluster number %s" % (str(i)))
    plt.ylabel("z-scored standardized gene expression")
    plt.xlabel("Differentiation Day")
    #plt.savefig("mirna_super_cluster_" + str(i) + ".svg",
    #            dpi=600,
    #            transparent=True,
    #            quality=90,
    #            bbox_inches="tight")
